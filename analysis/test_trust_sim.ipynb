# %%
import avapi  # to set the registries
import avstack  # to set the registries
import simulation  # to set the registries

from datetime import datetime
from simulation import TrustSimulation
# Out:
# WARNING:root:MobileAgent is already registered in agents at simulation.agents
# WARNING:root:StaticAgent is already registered in agents at simulation.agents
# WARNING:root:CommandCenter is already registered in agents at simulation.agents

# %%
t_start = datetime.now()
agents = [
    {"type": "MobileAgent", "ID": 0, "t_start": t_start},
    {"type": "StaticAgent", "ID": 1, "t_start": t_start},
    {"type": "StaticAgent", "ID": 2, "t_start": t_start},
    {"type": "StaticAgent", "ID": 3, "t_start": t_start},
]
command_center = {"type": "CommandCenter", "t_start": t_start}
replayer = {"type": "DatasetReplayer", "scene_index": 0}
trust_estimator = {"type": "TrustEstimator"}
simulator = TrustSimulation(
    agents=agents,
    command_center=command_center,
    dataset_replayer=replayer,
    trust_estimator=trust_estimator,
)
# Out:
# A `ConcaveHullLidarFOVEstimator` instance is built from registry, and its implementation can be found in simulation.fov_estimator
# Loads checkpoint by local backend from path: /home/spencer/Documents/Projects/Research/multi-agent/carla-collaborative/submodules/lib-avstack-core/third_party/mmdetection3d/work_dirs/pointpillars_hv_fpn_sbn-all_8xb4-2x_carla-3d-vehicle/epoch_24.pth
# A `MMDetObjectDetector3D` instance is built from registry, and its implementation can be found in avstack.modules.perception.object3d
# A `StoneSoupKalmanTracker3DBox` instance is built from registry, and its implementation can be found in avstack.modules.tracking.stonesoup
# A `MobileAgent` instance is built from registry, and its implementation can be found in simulation.agents
# A `ConcaveHullLidarFOVEstimator` instance is built from registry, and its implementation can be found in simulation.fov_estimator
# Loads checkpoint by local backend from path: /home/spencer/Documents/Projects/Research/multi-agent/carla-collaborative/submodules/lib-avstack-core/third_party/mmdetection3d/work_dirs/pointpillars_hv_fpn_sbn-all_8xb4-2x_carla-3d-infrastructure/epoch_24.pth
# A `MMDetObjectDetector3D` instance is built from registry, and its implementation can be found in avstack.modules.perception.object3d
# A `StoneSoupKalmanTracker3DBox` instance is built from registry, and its implementation can be found in avstack.modules.tracking.stonesoup
# A `StaticAgent` instance is built from registry, and its implementation can be found in simulation.agents
# A `ConcaveHullLidarFOVEstimator` instance is built from registry, and its implementation can be found in simulation.fov_estimator
# Loads checkpoint by local backend from path: /home/spencer/Documents/Projects/Research/multi-agent/carla-collaborative/submodules/lib-avstack-core/third_party/mmdetection3d/work_dirs/pointpillars_hv_fpn_sbn-all_8xb4-2x_carla-3d-infrastructure/epoch_24.pth
# A `MMDetObjectDetector3D` instance is built from registry, and its implementation can be found in avstack.modules.perception.object3d
# A `StoneSoupKalmanTracker3DBox` instance is built from registry, and its implementation can be found in avstack.modules.tracking.stonesoup
# A `StaticAgent` instance is built from registry, and its implementation can be found in simulation.agents
# A `ConcaveHullLidarFOVEstimator` instance is built from registry, and its implementation can be found in simulation.fov_estimator
# Loads checkpoint by local backend from path: /home/spencer/Documents/Projects/Research/multi-agent/carla-collaborative/submodules/lib-avstack-core/third_party/mmdetection3d/work_dirs/pointpillars_hv_fpn_sbn-all_8xb4-2x_carla-3d-infrastructure/epoch_24.pth
# A `MMDetObjectDetector3D` instance is built from registry, and its implementation can be found in avstack.modules.perception.object3d
# A `StoneSoupKalmanTracker3DBox` instance is built from registry, and its implementation can be found in avstack.modules.tracking.stonesoup
# A `StaticAgent` instance is built from registry, and its implementation can be found in simulation.agents
# A `MeasurementBasedMultiTracker` instance is built from registry, and its implementation can be found in avstack.modules.tracking.multisensor
# A `CommandCenter` instance is built from registry, and its implementation can be found in simulation.agents
# A `SampledAssignmentClusterer` instance is built from registry, and its implementation can be found in avstack.modules.clustering.clusterers
# A `ViewBasedPsm` instance is built from registry, and its implementation can be found in mate.measurement
# A `TrustBetaDistribution` instance is built from registry, and its implementation can be found in mate.distributions
# A `PriorInterpolationPropagator` instance is built from registry, and its implementation can be found in mate.propagator
# A `TrustBetaDistribution` instance is built from registry, and its implementation can be found in mate.distributions
# A `PriorInterpolationPropagator` instance is built from registry, and its implementation can be found in mate.propagator
# A `TrustEstimator` instance is built from registry, and its implementation can be found in mate.estimator
# A `CarlaScenesManager` instance is built from registry, and its implementation can be found in avapi.carla.dataset
# A `DatasetReplayer` instance is built from registry, and its implementation can be found in simulation.replayer

# %%
data = simulator.dataset_replayer.step()

# %%
data["agent_data"][0]["sensor_data"]["lidar"]

# %%
simulator.step()
# Out:
# /home/spencer/.cache/pypoetry/virtualenvs/mat-ue-6K6rSsfX-py3.10/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 simulator.step()
#
# File ~/Documents/Projects/Research/multi-agent/multi-agent-trust-ue/analysis/simulation/simulator.py:53, in TrustSimulation.step(self)
#      51 # store necessary data
#      52 agent_poses[agent_ID] = platform
# ---> 53 agent_fovs[agent_ID] = self.agents[agent_ID].get_fov_global()
#      54 agent_dets[agent_ID] = self.agents[agent_ID].get_detections_global()
#      55 agent_tracks[agent_ID] = self.agents[agent_ID].get_tracks_global()
#
# AttributeError: 'MobileAgent' object has no attribute 'get_fov_global'
